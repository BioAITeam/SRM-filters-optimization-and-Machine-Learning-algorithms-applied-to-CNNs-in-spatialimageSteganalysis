# %% [markdown]
# # VGG19-Net

# %% [markdown]
# ## Libraries

# %%
from scipy import misc, ndimage, signal
from sklearn.model_selection  import train_test_split
import numpy
import numpy as np
import random
import ntpath
import os
import pandas as pd
import numpy as np
import matplotlib as mpl
import matplotlib.pyplot as plt
import matplotlib.colors as colors
from keras import optimizers 
from keras import regularizers
import tensorflow as tf
import cv2
from time import time
import time as tm
import datetime
from operator import itemgetter
import glob
from skimage.util.shape import view_as_blocks
from keras.utils import np_utils
from keras.utils import to_categorical

# %% [markdown]
# ## GPU

# %% [raw]
# #USE OF CPU, WHEN IS NOT AVAILABLE THE GPU
# os.environ["CUDA_DEVICE_ORDER"] = "PCI_BUS_ID"
# os.environ['CUDA_VISIBLE_DEVICES'] = '-1'
# if tf.test.gpu_device_name():
#     print('GPU found')
# else:
#     print("No GPU found")

# %%
# !nvidia-smi
#!kill PIDnumber
# Out:
# Thu Feb 18 15:01:41 2021
# +-----------------------------------------------------------------------------+
# | NVIDIA-SMI 450.102.04   Driver Version: 450.102.04   CUDA Version: 11.0     |
# |-------------------------------+----------------------+----------------------+
# | GPU  Name        Persistence-M| Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp  Perf  Pwr:Usage/Cap|         Memory-Usage | GPU-Util  Compute M. |
# |                               |                      |               MIG M. |
# |===============================+======================+======================|
# |   0  GeForce RTX 208...  Off  | 00000000:0A:00.0  On |                  N/A |
# | 37%   50C    P8    16W / 250W |    369MiB / 11016MiB |      0%      Default |
# |                               |                      |                  N/A |
# +-------------------------------+----------------------+----------------------+
#
# +-----------------------------------------------------------------------------+
# | Processes:                                                                  |
# |  GPU   GI   CI        PID   Type   Process name                  GPU Memory |
# |        ID   ID                                                   Usage      |
# |=============================================================================|
# |    0   N/A  N/A      1341      G   /usr/lib/xorg/Xorg                 72MiB |
# |    0   N/A  N/A      1989      G   /usr/lib/xorg/Xorg                107MiB |
# |    0   N/A  N/A      2118      G   /usr/bin/gnome-shell              170MiB |
# +-----------------------------------------------------------------------------+

# %% [markdown]
# ## 30 SRM filters for preprocessing and the activation function

# %%
################################################## 30 SRM FILTERS
srm_weights = np.load('SRM_Kernels1.npy') 
biasSRM=numpy.ones(30)
print (srm_weights.shape)
################################################## TLU ACTIVATION FUNCTION
#3xTanH ACTIVATION FUNCTION
def Tanh3(x):
    tanh3 = tf.keras.activations.tanh(x)*3
    return tanh3
##################################################
# Out:
# (5, 5, 1, 30)

# %% [markdown]
# ## Paths to save trained models epoch by epoch and final accuracy and loss curves

# %%
path_log_base = './logs'
path_img_base = './images'
if not os.path.exists(path_log_base):
    os.makedirs(path_log_base)
if not os.path.exists(path_img_base):
    os.makedirs(path_img_base)

# %% [markdown]
# ## Defining different functions to work with the architecture

# %%
def train(model, X_train, y_train, X_valid, y_valid, X_test, y_test, batch_size, epochs, model_name=""):
    start_time = tm.time()
    log_dir=path_log_base+"/"+model_name+"_"+str(datetime.datetime.now().isoformat()[:19].replace("T", "_").replace(":","-"))
    tensorboard = tf.keras.callbacks.TensorBoard(log_dir, histogram_freq=1)
    filepath = log_dir+"/saved-model-{epoch:03d}-{val_accuracy:.4f}.hdf5"
    checkpoint = tf.keras.callbacks.ModelCheckpoint(filepath, monitor='val_accuracy', save_best_only=False, mode='max')
    model.reset_states()
    
    global lossTEST
    global accuracyTEST
    global lossTRAIN
    global accuracyTRAIN
    global lossVALID
    global accuracyVALID
    lossTEST,accuracyTEST   = model.evaluate(X_test, y_test,verbose=None)
    lossTRAIN,accuracyTRAIN = model.evaluate(X_train, y_train,verbose=None)
    lossVALID,accuracyVALID = model.evaluate(X_valid, y_valid,verbose=None)

    global history
    global model_Name
    global log_Dir
    model_Name = model_name
    log_Dir = log_dir
    print("Starting the training...")
    history=model.fit(X_train, y_train, epochs=epochs, 
                      callbacks=[tensorboard,checkpoint], 
                      batch_size=batch_size,validation_data=(X_valid, y_valid),verbose=2)
    
    metrics = model.evaluate(X_test, y_test, verbose=0)
     
    TIME = tm.time() - start_time
    print("Time "+model_name+" = %s [seconds]" % TIME)
    
    print("\n")
    print(log_dir)
    return {k:v for k,v in zip (model.metrics_names, metrics)}

# %%
def Final_Results_Test(PATH_trained_models):
    global AccTest
    global LossTest
    AccTest = []
    LossTest= [] 
    B_accuracy = 0 #B --> Best
    for filename in sorted(os.listdir(PATH_trained_models)):
        if filename != ('train') and filename != ('validation'):
            print(filename)
            model = tf.keras.models.load_model(PATH_trained_models+'/'+filename, custom_objects={'Tanh3':Tanh3})
            loss,accuracy = model.evaluate(X_test, y_test,verbose=0)
            print(f'Loss={loss:.4f} y Accuracy={accuracy:0.4f}'+'\n')
            BandAccTest  = accuracy
            BandLossTest = loss
            AccTest.append(BandAccTest)    
            LossTest.append(BandLossTest)  
            
            if accuracy > B_accuracy:
                B_accuracy = accuracy
                B_loss = loss
                B_name = filename
    
    print("\n\nBest")
    print(B_name)
    print(f'Loss={B_loss:.4f} y Accuracy={B_accuracy:0.4f}'+'\n')

# %%
def graphics(history, AccTest, LossTest, log_Dir, model_Name, lossTEST, lossTRAIN, lossVALID, accuracyTEST, accuracyTRAIN, accuracyVALID):
    numbers=AccTest
    numbers_sort = sorted(enumerate(numbers), key=itemgetter(1),  reverse=True)
    for i in range(int(len(numbers)*(0.05))): #5% total epochs
        index, value = numbers_sort[i]
        print("Test Accuracy {}, epoch:{}\n".format(value, index+1))
    
    print("")
    
    numbers=history.history['accuracy']
    numbers_sort = sorted(enumerate(numbers), key=itemgetter(1),  reverse=True)
    for i in range(int(len(numbers)*(0.05))): #5% total epochs
        index, value = numbers_sort[i]
        print("Train Accuracy {}, epoch:{}\n".format(value, index+1))
    
    print("")
    
    numbers=history.history['val_accuracy']
    numbers_sort = sorted(enumerate(numbers), key=itemgetter(1),  reverse=True)
    for i in range(int(len(numbers)*(0.05))): #5% total epochs
        index, value = numbers_sort[i]
        print("Validation Accuracy {}, epoch:{}\n".format(value, index+1))

    with plt.style.context('seaborn-white'):
        plt.figure(figsize=(10, 10))
        plt.plot(np.concatenate([np.array([accuracyTRAIN]),np.array(history.history['accuracy'])],axis=0))
        plt.plot(np.concatenate([np.array([accuracyVALID]),np.array(history.history['val_accuracy'])],axis=0))
        plt.plot(np.concatenate([np.array([accuracyTEST]),np.array(AccTest)],axis=0)) #Test
        plt.title('Accuracy Vs Epoch')
        plt.ylabel('Accuracy')
        plt.xlabel('Epoch')
        plt.legend(['Train', 'Validation', 'Test'], loc='upper left')
        plt.grid('on')
        plt.savefig(path_img_base+'/Accuracy_VGG19_Net2'+model_Name+'.eps', format='eps')
        plt.savefig(path_img_base+'/Accuracy_VGG19_Net2'+model_Name+'.svg', format='svg')
        plt.savefig(path_img_base+'/Accuracy_VGG19_Net2'+model_Name+'.pdf', format='pdf')     
        plt.show()
        
        plt.figure(figsize=(10, 10))
        plt.plot(np.concatenate([np.array([lossTRAIN]),np.array(history.history['loss'])],axis=0))
        plt.plot(np.concatenate([np.array([lossVALID]),np.array(history.history['val_loss'])],axis=0))
        plt.plot(np.concatenate([np.array([lossTEST]),np.array(LossTest)],axis=0)) #Test
        plt.title('Loss Vs Epoch')
        plt.ylabel('Loss')
        plt.xlabel('Epoch')
        plt.legend(['Train', 'Validation', 'Test'], loc='upper left')
        plt.grid('on')
        plt.savefig(path_img_base+'/Loss_VGG19_Net2'+model_Name+'.eps', format='eps')
        plt.savefig(path_img_base+'/Loss_VGG19_Net2'+model_Name+'.svg', format='svg')
        plt.savefig(path_img_base+'/Loss_VGG19_Net2'+model_Name+'.pdf', format='pdf') 
        plt.show()

# %% [markdown]
# # Working with BOSSbase 1.01

# %%
n=256
def load_images(path_pattern):
    files=glob.glob(path_pattern)
    X=[]
    for f in sorted(files):
        I = cv2.imread(f, cv2.IMREAD_GRAYSCALE)
        patches = view_as_blocks(I, (n, n))
        for i in range(patches.shape[0]):
            for j in range(patches.shape[1]):
                X.append( [ patches[i,j] ] )
    X=numpy.array(X)
    return X

pathc = '../DATABASES/BOSSbase-1.01'
paths = '../DATABASES/BOSSbase-1.01/WOW/0.4bpp'

Xc_ = load_images(pathc+'/cover/*.pgm') ##COVER IMAGES
Xs_ = load_images(paths+'/stego/*.pgm') ##STEGO IMAGES
X_  = (numpy.vstack((Xc_, Xs_)))
Xt_ = (numpy.hstack(([0]*len(Xc_), [1]*len(Xs_))))
Xt_ = np_utils.to_categorical(Xt_, 2)
X_  = np.rollaxis(X_,1,4)  #channel axis shifted to last axis

print("Total image data and labels",X_.shape,Xt_.shape)
#Cover hasta las 10000 ##Train hasta las 4000 ##Valid hasta de las 4000 a las 5000 ##Test de las 5000 a las 10000
X_train = np.concatenate([X_[0:4000],X_[10000:14000]],axis=0)
X_valid = np.concatenate([X_[4000:5000],X_[14000:15000]],axis=0)
X_test  = np.concatenate([X_[5000:10000],X_[15000:20000]],axis=0)
y_train = np.concatenate([Xt_[0:4000],Xt_[10000:14000]],axis=0)
y_valid = np.concatenate([Xt_[4000:5000],Xt_[14000:15000]],axis=0)
y_test  = np.concatenate([Xt_[5000:10000],Xt_[15000:20000]],axis=0)
#Controled randomized data for training
X_dat0, X_dat1, y_dat0, y_dat1 = train_test_split(X_train, y_train, test_size=0.50, random_state=64) 
X_train = np.concatenate([X_dat0,X_dat1],axis=0) 
y_train = np.concatenate([y_dat0,y_dat1],axis=0) 
print(X_train.shape)
print(y_train.shape)
print(X_valid.shape)
print(y_valid.shape)
print(X_test.shape)
print(y_test.shape)
# Out:
# Total image data and labels (20000, 256, 256, 1) (20000, 2)
# (8000, 256, 256, 1)
# (8000, 2)
# (2000, 256, 256, 1)
# (2000, 2)
# (10000, 256, 256, 1)
# (10000, 2)

# %% [markdown]
# # WITH SRM BIFURCATION LIKE GBRAS

# %%
def get_vgg19_avg(img_size=256):
    
    #Inputs
    inputs = tf.keras.Input(shape=(img_size,img_size,1), name="input_1")
    
    #Block 1
    layers_ty = tf.keras.layers.Conv2D(30, (5,5), weights=[srm_weights,biasSRM], strides=(1,1), padding='same', trainable=False, activation=Tanh3, use_bias=True)(inputs)
    layers_tn = tf.keras.layers.Conv2D(30, (5,5), weights=[srm_weights,biasSRM], strides=(1,1), padding='same', trainable=True, activation=Tanh3, use_bias=True)(inputs)

    layers = tf.keras.layers.add([layers_ty, layers_tn])
    
    layers = tf.keras.layers.Conv2D(64, (3,3), strides=(1,1),padding="same", kernel_initializer='glorot_normal', kernel_regularizer=tf.keras.regularizers.l2(0.0001),bias_regularizer=tf.keras.regularizers.l2(0.0001))(layers) 
    layers = tf.keras.layers.ReLU(negative_slope=0.1, threshold=0)(layers)
    layers = tf.keras.layers.Lambda(tf.keras.backend.abs)(layers)
    layers = tf.keras.layers.BatchNormalization(momentum=0.2, epsilon=0.001, center=True, scale=True, trainable=True, fused=None, renorm=False, renorm_clipping=None, renorm_momentum=0.4, adjustment=None)(layers)
    layers = tf.keras.layers.Concatenate()([layers, layers, layers])
    layers = tf.keras.layers.SpatialDropout2D(rate=0.1)(layers)
    layers = tf.keras.layers.Conv2D(64, (3,3), strides=(1,1),padding="same", kernel_initializer='glorot_normal', kernel_regularizer=tf.keras.regularizers.l2(0.0001),bias_regularizer=tf.keras.regularizers.l2(0.0001))(layers) 
    layers = tf.keras.layers.ReLU(negative_slope=0.1, threshold=0)(layers)
    layers = tf.keras.layers.Lambda(tf.keras.backend.abs)(layers)
    layers = tf.keras.layers.BatchNormalization(momentum=0.2, epsilon=0.001, center=True, scale=True, trainable=True, fused=None, renorm=False, renorm_clipping=None, renorm_momentum=0.4, adjustment=None)(layers)
    layers = tf.keras.layers.AveragePooling2D((2,2), strides= (2,2))(layers)
    #Block 2
    layers = tf.keras.layers.SpatialDropout2D(rate=0.1, data_format="channels_last")(layers)
    layers = tf.keras.layers.Conv2D(128, (3,3), strides=(1,1),padding="same", kernel_initializer='glorot_normal', kernel_regularizer=tf.keras.regularizers.l2(0.0001),bias_regularizer=tf.keras.regularizers.l2(0.0001))(layers) 
    layers = tf.keras.layers.ReLU(negative_slope=0.1, threshold=0)(layers)
    layers = tf.keras.layers.Lambda(tf.keras.backend.abs)(layers)
    layers = tf.keras.layers.BatchNormalization(momentum=0.2, epsilon=0.001, center=True, scale=True, trainable=True, fused=None, renorm=False, renorm_clipping=None, renorm_momentum=0.4, adjustment=None)(layers)
    layers = tf.keras.layers.SpatialDropout2D(rate=0.1, data_format="channels_last")(layers)
    layers = tf.keras.layers.Conv2D(128, (3,3), strides=(1,1),padding="same", kernel_initializer='glorot_normal', kernel_regularizer=tf.keras.regularizers.l2(0.0001),bias_regularizer=tf.keras.regularizers.l2(0.0001))(layers) 
    layers = tf.keras.layers.ReLU(negative_slope=0.1, threshold=0)(layers)
    layers = tf.keras.layers.Lambda(tf.keras.backend.abs)(layers)
    layers = tf.keras.layers.BatchNormalization(momentum=0.2, epsilon=0.001, center=True, scale=True, trainable=True, fused=None, renorm=False, renorm_clipping=None, renorm_momentum=0.4, adjustment=None)(layers)
    layers = tf.keras.layers.AveragePooling2D((2,2), strides= (2,2))(layers)
    #Block 3
    layers = tf.keras.layers.SpatialDropout2D(rate=0.1, data_format="channels_last")(layers)
    layers = tf.keras.layers.Conv2D(256, (3,3), strides=(1,1),padding="same", kernel_initializer='glorot_normal', kernel_regularizer=tf.keras.regularizers.l2(0.0001),bias_regularizer=tf.keras.regularizers.l2(0.0001))(layers) 
    layers = tf.keras.layers.ReLU(negative_slope=0.1, threshold=0)(layers)
    layers = tf.keras.layers.Lambda(tf.keras.backend.abs)(layers)
    layers = tf.keras.layers.BatchNormalization(momentum=0.2, epsilon=0.001, center=True, scale=True, trainable=True, fused=None, renorm=False, renorm_clipping=None, renorm_momentum=0.4, adjustment=None)(layers)
    layers = tf.keras.layers.SpatialDropout2D(rate=0.1, data_format="channels_last")(layers)
    layers = tf.keras.layers.Conv2D(256, (3,3), strides=(1,1),padding="same", kernel_initializer='glorot_normal', kernel_regularizer=tf.keras.regularizers.l2(0.0001),bias_regularizer=tf.keras.regularizers.l2(0.0001))(layers) 
    layers = tf.keras.layers.ReLU(negative_slope=0.1, threshold=0)(layers)
    layers = tf.keras.layers.Lambda(tf.keras.backend.abs)(layers)
    layers = tf.keras.layers.BatchNormalization(momentum=0.2, epsilon=0.001, center=True, scale=True, trainable=True, fused=None, renorm=False, renorm_clipping=None, renorm_momentum=0.4, adjustment=None)(layers)
    layers = tf.keras.layers.Conv2D(256, (3,3), strides=(1,1),padding="same", kernel_initializer='glorot_normal', kernel_regularizer=tf.keras.regularizers.l2(0.0001),bias_regularizer=tf.keras.regularizers.l2(0.0001))(layers) 
    layers = tf.keras.layers.ReLU(negative_slope=0.1, threshold=0)(layers)
    layers = tf.keras.layers.Lambda(tf.keras.backend.abs)(layers)
    layers = tf.keras.layers.BatchNormalization(momentum=0.2, epsilon=0.001, center=True, scale=True, trainable=True, fused=None, renorm=False, renorm_clipping=None, renorm_momentum=0.4, adjustment=None)(layers)
    layers = tf.keras.layers.Conv2D(256, (3,3), strides=(1,1),padding="same", kernel_initializer='glorot_normal', kernel_regularizer=tf.keras.regularizers.l2(0.0001),bias_regularizer=tf.keras.regularizers.l2(0.0001))(layers) 
    layers = tf.keras.layers.ReLU(negative_slope=0.1, threshold=0)(layers)
    layers = tf.keras.layers.Lambda(tf.keras.backend.abs)(layers)
    layers = tf.keras.layers.BatchNormalization(momentum=0.2, epsilon=0.001, center=True, scale=True, trainable=True, fused=None, renorm=False, renorm_clipping=None, renorm_momentum=0.4, adjustment=None)(layers)
    layers = tf.keras.layers.AveragePooling2D((2,2), strides= (2,2))(layers)
    #Block 4
    layers = tf.keras.layers.SpatialDropout2D(rate=0.1, data_format="channels_last")(layers)
    layers = tf.keras.layers.Conv2D(512, (3,3), strides=(1,1),padding="same", kernel_initializer='glorot_normal', kernel_regularizer=tf.keras.regularizers.l2(0.0001),bias_regularizer=tf.keras.regularizers.l2(0.0001))(layers) 
    layers = tf.keras.layers.ReLU(negative_slope=0.1, threshold=0)(layers)
    layers = tf.keras.layers.Lambda(tf.keras.backend.abs)(layers)
    layers = tf.keras.layers.BatchNormalization(momentum=0.2, epsilon=0.001, center=True, scale=True, trainable=True, fused=None, renorm=False, renorm_clipping=None, renorm_momentum=0.4, adjustment=None)(layers)
    layers = tf.keras.layers.SpatialDropout2D(rate=0.1, data_format="channels_last")(layers)
    layers = tf.keras.layers.Conv2D(512, (3,3), strides=(1,1),padding="same", kernel_initializer='glorot_normal', kernel_regularizer=tf.keras.regularizers.l2(0.0001),bias_regularizer=tf.keras.regularizers.l2(0.0001))(layers) 
    layers = tf.keras.layers.ReLU(negative_slope=0.1, threshold=0)(layers)
    layers = tf.keras.layers.Lambda(tf.keras.backend.abs)(layers)
    layers = tf.keras.layers.BatchNormalization(momentum=0.2, epsilon=0.001, center=True, scale=True, trainable=True, fused=None, renorm=False, renorm_clipping=None, renorm_momentum=0.4, adjustment=None)(layers)
    layers = tf.keras.layers.Conv2D(512, (3,3), strides=(1,1),padding="same", kernel_initializer='glorot_normal', kernel_regularizer=tf.keras.regularizers.l2(0.0001),bias_regularizer=tf.keras.regularizers.l2(0.0001))(layers) 
    layers = tf.keras.layers.ReLU(negative_slope=0.1, threshold=0)(layers)
    layers = tf.keras.layers.Lambda(tf.keras.backend.abs)(layers)
    layers = tf.keras.layers.BatchNormalization(momentum=0.2, epsilon=0.001, center=True, scale=True, trainable=True, fused=None, renorm=False, renorm_clipping=None, renorm_momentum=0.4, adjustment=None)(layers)
    layers = tf.keras.layers.Conv2D(512, (3,3), strides=(1,1),padding="same", kernel_initializer='glorot_normal', kernel_regularizer=tf.keras.regularizers.l2(0.0001),bias_regularizer=tf.keras.regularizers.l2(0.0001))(layers) 
    layers = tf.keras.layers.ReLU(negative_slope=0.1, threshold=0)(layers)
    layers = tf.keras.layers.Lambda(tf.keras.backend.abs)(layers)
    layers = tf.keras.layers.BatchNormalization(momentum=0.2, epsilon=0.001, center=True, scale=True, trainable=True, fused=None, renorm=False, renorm_clipping=None, renorm_momentum=0.4, adjustment=None)(layers)
    layers = tf.keras.layers.AveragePooling2D((2,2), strides= (2,2))(layers)

    #Block 5
    layers = tf.keras.layers.SpatialDropout2D(rate=0.1, data_format="channels_last")(layers)
    layers = tf.keras.layers.Conv2D(512, (3,3), strides=(1,1),padding="same", kernel_initializer='glorot_normal', kernel_regularizer=tf.keras.regularizers.l2(0.0001),bias_regularizer=tf.keras.regularizers.l2(0.0001))(layers) 
    layers = tf.keras.layers.ReLU(negative_slope=0.1, threshold=0)(layers)
    layers = tf.keras.layers.Lambda(tf.keras.backend.abs)(layers)
    layers = tf.keras.layers.BatchNormalization(momentum=0.2, epsilon=0.001, center=True, scale=True, trainable=True, fused=None, renorm=False, renorm_clipping=None, renorm_momentum=0.4, adjustment=None)(layers)
    layers = tf.keras.layers.SpatialDropout2D(rate=0.1, data_format="channels_last")(layers)
    layers = tf.keras.layers.Conv2D(512, (3,3), strides=(1,1),padding="same", kernel_initializer='glorot_normal', kernel_regularizer=tf.keras.regularizers.l2(0.0001),bias_regularizer=tf.keras.regularizers.l2(0.0001))(layers) 
    layers = tf.keras.layers.ReLU(negative_slope=0.1, threshold=0)(layers)
    layers = tf.keras.layers.Lambda(tf.keras.backend.abs)(layers)
    layers = tf.keras.layers.BatchNormalization(momentum=0.2, epsilon=0.001, center=True, scale=True, trainable=True, fused=None, renorm=False, renorm_clipping=None, renorm_momentum=0.4, adjustment=None)(layers)
    layers = tf.keras.layers.Conv2D(512, (3,3), strides=(1,1),padding="same", kernel_initializer='glorot_normal', kernel_regularizer=tf.keras.regularizers.l2(0.0001),bias_regularizer=tf.keras.regularizers.l2(0.0001))(layers) 
    layers = tf.keras.layers.ReLU(negative_slope=0.1, threshold=0)(layers)
    layers = tf.keras.layers.Lambda(tf.keras.backend.abs)(layers)
    layers = tf.keras.layers.BatchNormalization(momentum=0.2, epsilon=0.001, center=True, scale=True, trainable=True, fused=None, renorm=False, renorm_clipping=None, renorm_momentum=0.4, adjustment=None)(layers)
    layers = tf.keras.layers.AveragePooling2D((2,2), strides= (2,2))(layers)
    layers = tf.keras.layers.Concatenate()([layers, layers, layers])
    layers = tf.keras.layers.GlobalAveragePooling2D(data_format="channels_last")(layers)
    #Block 6
    #FC
    layers = tf.keras.layers.Dense(128,kernel_initializer='glorot_normal',kernel_regularizer=tf.keras.regularizers.l2(0.0001),bias_regularizer=tf.keras.regularizers.l2(0.0001))(layers)
    layers = tf.keras.layers.ReLU(negative_slope=0.1, threshold=0)(layers)
    layers = tf.keras.layers.Dense(64,kernel_initializer='glorot_normal',kernel_regularizer=tf.keras.regularizers.l2(0.0001),bias_regularizer=tf.keras.regularizers.l2(0.0001))(layers)
    layers = tf.keras.layers.ReLU(negative_slope=0.1, threshold=0)(layers)
    layers = tf.keras.layers.Dense(32,kernel_initializer='glorot_normal',kernel_regularizer=tf.keras.regularizers.l2(0.0001),bias_regularizer=tf.keras.regularizers.l2(0.0001))(layers)
    layers = tf.keras.layers.ReLU(negative_slope=0.1, threshold=0)(layers)
   
    #Softmax
    predictions = tf.keras.layers.Dense(2, activation="softmax", name="output_1",kernel_regularizer=tf.keras.regularizers.l2(0.0001),bias_regularizer=tf.keras.regularizers.l2(0.0001))(layers)
    model =tf.keras.Model(inputs = inputs, outputs=predictions)
    #Compile
    optimizer = tf.keras.optimizers.SGD(learning_rate=0.005, momentum=0.95)
    
  
    model.compile(optimizer= optimizer,loss='binary_crossentropy',metrics=['accuracy'])
        
    print ("VGG19 AveragePooling model generated")

    return model


model2 = get_vgg19_avg(img_size=256)
# Out:
# VGG19 AveragePooling model generated

# %%
tf.keras.utils.plot_model(model2, show_shapes=True)

# %%
train(model2, X_train, y_train, X_valid, y_valid, X_test, y_test, batch_size=16, epochs=150, model_name="model_VGG19-Net_WOW_04bppBIFURCATION") 
#WOW
# Out:
# Starting the training...
# Epoch 1/150
# 500/500 - 147s - loss: 1.2148 - accuracy: 0.5026 - val_loss: 1.2026 - val_accuracy: 0.5000
# Epoch 2/150
# 500/500 - 148s - loss: 1.1948 - accuracy: 0.4999 - val_loss: 1.1877 - val_accuracy: 0.5065
# Epoch 3/150
# 500/500 - 148s - loss: 1.1836 - accuracy: 0.5063 - val_loss: 1.1792 - val_accuracy: 0.5000
# Epoch 4/150
# 500/500 - 148s - loss: 1.1741 - accuracy: 0.5042 - val_loss: 1.1681 - val_accuracy: 0.5010
# Epoch 5/150
# 500/500 - 148s - loss: 1.1643 - accuracy: 0.5006 - val_loss: 1.1582 - val_accuracy: 0.5135
# Epoch 6/150
# 500/500 - 148s - loss: 1.1554 - accuracy: 0.5005 - val_loss: 1.1499 - val_accuracy: 0.5025
# Epoch 7/150
# 500/500 - 148s - loss: 1.1459 - accuracy: 0.5008 - val_loss: 1.1402 - val_accuracy: 0.5080
# Epoch 8/150
# 500/500 - 148s - loss: 1.1373 - accuracy: 0.4978 - val_loss: 1.1313 - val_accuracy: 0.5020
# Epoch 9/150
# 500/500 - 148s - loss: 1.1280 - accuracy: 0.4963 - val_loss: 1.1221 - val_accuracy: 0.5125
# Epoch 10/150
# 500/500 - 148s - loss: 1.1189 - accuracy: 0.5030 - val_loss: 1.1141 - val_accuracy: 0.5165
# Epoch 11/150
# 500/500 - 148s - loss: 1.1105 - accuracy: 0.5061 - val_loss: 1.1049 - val_accuracy: 0.5165
# Epoch 12/150
# 500/500 - 148s - loss: 1.1029 - accuracy: 0.5009 - val_loss: 1.0972 - val_accuracy: 0.5215
# Epoch 13/150
# 500/500 - 148s - loss: 1.0949 - accuracy: 0.5013 - val_loss: 1.0882 - val_accuracy: 0.5240
# Epoch 14/150
# 500/500 - 148s - loss: 1.0863 - accuracy: 0.5033 - val_loss: 1.0806 - val_accuracy: 0.5010
# Epoch 15/150
# 500/500 - 148s - loss: 1.0785 - accuracy: 0.5090 - val_loss: 1.0739 - val_accuracy: 0.5115
# Epoch 16/150
# 500/500 - 148s - loss: 1.0692 - accuracy: 0.5205 - val_loss: 1.0675 - val_accuracy: 0.5005
# Epoch 17/150
# 500/500 - 148s - loss: 1.0634 - accuracy: 0.5042 - val_loss: 1.0647 - val_accuracy: 0.5035
# Epoch 18/150
# 500/500 - 148s - loss: 1.0550 - accuracy: 0.5203 - val_loss: 1.0480 - val_accuracy: 0.5510
# Epoch 19/150
# 500/500 - 148s - loss: 1.0475 - accuracy: 0.5214 - val_loss: 1.0445 - val_accuracy: 0.5415
# Epoch 20/150
# 500/500 - 148s - loss: 1.0366 - accuracy: 0.5293 - val_loss: 1.0247 - val_accuracy: 0.5565
# Epoch 21/150
# 500/500 - 148s - loss: 1.0285 - accuracy: 0.5334 - val_loss: 1.0303 - val_accuracy: 0.5285
# Epoch 22/150
# 500/500 - 148s - loss: 1.0149 - accuracy: 0.5534 - val_loss: 0.9943 - val_accuracy: 0.5725
# Epoch 23/150
# 500/500 - 148s - loss: 0.9948 - accuracy: 0.5676 - val_loss: 0.9633 - val_accuracy: 0.6220
# Epoch 24/150
# 500/500 - 148s - loss: 0.9830 - accuracy: 0.5790 - val_loss: 0.9698 - val_accuracy: 0.6010
# Epoch 25/150
# 500/500 - 148s - loss: 0.9645 - accuracy: 0.5910 - val_loss: 0.9198 - val_accuracy: 0.6450
# Epoch 26/150
# 500/500 - 148s - loss: 0.9445 - accuracy: 0.6033 - val_loss: 0.8862 - val_accuracy: 0.6635
# Epoch 27/150
# 500/500 - 148s - loss: 0.9160 - accuracy: 0.6269 - val_loss: 0.8564 - val_accuracy: 0.6550
# Epoch 28/150
# 500/500 - 148s - loss: 0.9024 - accuracy: 0.6399 - val_loss: 0.8160 - val_accuracy: 0.7010
# Epoch 29/150
# 500/500 - 148s - loss: 0.8862 - accuracy: 0.6446 - val_loss: 0.8676 - val_accuracy: 0.6825
# Epoch 30/150
# 500/500 - 148s - loss: 0.8685 - accuracy: 0.6553 - val_loss: 0.7797 - val_accuracy: 0.7300
# Epoch 31/150
# 500/500 - 148s - loss: 0.8490 - accuracy: 0.6626 - val_loss: 0.7734 - val_accuracy: 0.7205
# Epoch 32/150
# 500/500 - 148s - loss: 0.8401 - accuracy: 0.6696 - val_loss: 0.7306 - val_accuracy: 0.7635
# Epoch 33/150
# 500/500 - 148s - loss: 0.8147 - accuracy: 0.6940 - val_loss: 0.7687 - val_accuracy: 0.7300
# Epoch 34/150
# 500/500 - 148s - loss: 0.7952 - accuracy: 0.7007 - val_loss: 0.6930 - val_accuracy: 0.7705
# Epoch 35/150
# 500/500 - 148s - loss: 0.3676 - accuracy: 0.8679 - val_loss: 0.4049 - val_accuracy: 0.8530
# Epoch 147/150
# 500/500 - 148s - loss: 0.3675 - accuracy: 0.8735 - val_loss: 0.4064 - val_accuracy: 0.8575
# Epoch 148/150
# 500/500 - 148s - loss: 0.3711 - accuracy: 0.8716 - val_loss: 0.4036 - val_accuracy: 0.8570
# Epoch 149/150
# 500/500 - 148s - loss: 0.3615 - accuracy: 0.8720 - val_loss: 0.3978 - val_accuracy: 0.8635
# Epoch 150/150
# 500/500 - 148s - loss: 0.3712 - accuracy: 0.8700 - val_loss: 0.4686 - val_accuracy: 0.8310
# Time model_VGG19-Net_WOW_04bppBIFURCATION = 22470.690014362335 [seconds]
#
#
# ./logs/model_VGG19-Net_WOW_04bppBIFURCATION_2021-02-18_07-16-18
# {'loss': 0.4359034299850464, 'accuracy': 0.8495000004768372}

# %%
Final_Results_Test(log_Dir)
# Out:
# saved-model-001-0.5000.hdf5
# Loss=1.2028 y Accuracy=0.4996
#
# saved-model-002-0.5065.hdf5
# Loss=1.1878 y Accuracy=0.5024
#
# saved-model-003-0.5000.hdf5
# Loss=1.1793 y Accuracy=0.4992
#
# saved-model-004-0.5010.hdf5
# Loss=1.1681 y Accuracy=0.5033
#
# saved-model-005-0.5135.hdf5
# Loss=1.1580 y Accuracy=0.5110
#
# saved-model-006-0.5025.hdf5
# Loss=1.1499 y Accuracy=0.5001
#
# saved-model-007-0.5080.hdf5
# Loss=1.1402 y Accuracy=0.5065
#
# saved-model-008-0.5020.hdf5
# Loss=1.1313 y Accuracy=0.5030
#
# saved-model-009-0.5125.hdf5
# Loss=1.1222 y Accuracy=0.5097
#
# saved-model-010-0.5165.hdf5
# Loss=1.1140 y Accuracy=0.5240
#
# saved-model-011-0.5165.hdf5
# Loss=1.1050 y Accuracy=0.5121
#
# saved-model-012-0.5215.hdf5
# Loss=1.0969 y Accuracy=0.5202
#
# saved-model-013-0.5240.hdf5
# Loss=1.0881 y Accuracy=0.5172
#
# saved-model-014-0.5010.hdf5
# Loss=1.0805 y Accuracy=0.5002
#
# saved-model-015-0.5115.hdf5
# Loss=1.0731 y Accuracy=0.5159
#
# saved-model-016-0.5005.hdf5
# Loss=1.0674 y Accuracy=0.4976
#
# saved-model-017-0.5035.hdf5
# Loss=1.0647 y Accuracy=0.5004
#
# saved-model-018-0.5510.hdf5
# Loss=1.0457 y Accuracy=0.5612
#
# saved-model-019-0.5415.hdf5
# Loss=1.0380 y Accuracy=0.5497
#
# saved-model-020-0.5565.hdf5
# Loss=1.0211 y Accuracy=0.5654
#
# saved-model-021-0.5285.hdf5
# Loss=1.0387 y Accuracy=0.5234
#
# saved-model-022-0.5725.hdf5
# Loss=0.9893 y Accuracy=0.5888
#
# saved-model-023-0.6220.hdf5
# Loss=0.9629 y Accuracy=0.6233
#
# saved-model-024-0.6010.hdf5
# Loss=0.9688 y Accuracy=0.6097
#
# saved-model-025-0.6450.hdf5
# Loss=0.9190 y Accuracy=0.6467
#
# saved-model-026-0.6635.hdf5
# Loss=0.8519 y Accuracy=0.6849
#
# saved-model-027-0.6550.hdf5
# Loss=0.8303 y Accuracy=0.6767
#
# saved-model-028-0.7010.hdf5
# Loss=0.7998 y Accuracy=0.7196
#
# saved-model-029-0.6825.hdf5
# Loss=0.8230 y Accuracy=0.7053
#
# saved-model-030-0.7300.hdf5
# Loss=0.7494 y Accuracy=0.7459
#
# saved-model-031-0.7205.hdf5
# Loss=0.7436 y Accuracy=0.7416
#
# saved-model-032-0.7635.hdf5
# Loss=0.7073 y Accuracy=0.7710
#
# saved-model-033-0.7300.hdf5
# Loss=0.7336 y Accuracy=0.7553
#
# saved-model-034-0.7705.hdf5
# Loss=0.6909 y Accuracy=0.7858
#
# saved-model-035-0.7750.hdf5
# Loss=0.6657 y Accuracy=0.7856
#
# saved-model-036-0.7720.hdf5
# Loss=0.6796 y Accuracy=0.7844
#
# saved-model-037-0.7970.hdf5
# Loss=0.6458 y Accuracy=0.7982
#
# saved-model-038-0.7930.hdf5
# Loss=0.6293 y Accuracy=0.8091
#
# saved-model-039-0.7940.hdf5
# Loss=0.6280 y Accuracy=0.8090
#
# saved-model-040-0.8065.hdf5
# Loss=0.6100 y Accuracy=0.8162
#
# saved-model-041-0.8135.hdf5
# Loss=0.5837 y Accuracy=0.8206
#
# saved-model-042-0.7800.hdf5
# Loss=0.6146 y Accuracy=0.8003
#
# saved-model-043-0.7955.hdf5
# Loss=0.6132 y Accuracy=0.8241
#
# saved-model-044-0.7880.hdf5
# Loss=0.6102 y Accuracy=0.8032
#
# saved-model-045-0.8015.hdf5
# Loss=0.5780 y Accuracy=0.8175
#
# saved-model-046-0.8085.hdf5
# Loss=0.5968 y Accuracy=0.8133
#
# saved-model-047-0.8190.hdf5
# Loss=0.5477 y Accuracy=0.8313
#
# saved-model-048-0.8035.hdf5
# Loss=0.6071 y Accuracy=0.8084
#
# saved-model-049-0.8215.hdf5
# Loss=0.5523 y Accuracy=0.8317
#
# saved-model-050-0.7940.hdf5
# Loss=0.5768 y Accuracy=0.8046
#
# saved-model-051-0.8320.hdf5
# Loss=0.5251 y Accuracy=0.8407
#
# saved-model-052-0.8325.hdf5
# Loss=0.5420 y Accuracy=0.8311
#
# saved-model-053-0.7995.hdf5
# Loss=0.5803 y Accuracy=0.8162
#
# saved-model-054-0.8100.hdf5
# Loss=0.5065 y Accuracy=0.8424
#
# saved-model-055-0.8430.hdf5
# Loss=0.5180 y Accuracy=0.8546
#
# saved-model-056-0.8255.hdf5
# Loss=0.5144 y Accuracy=0.8363
#
# saved-model-057-0.8325.hdf5
# Loss=0.4805 y Accuracy=0.8563
#
# saved-model-058-0.8375.hdf5
# Loss=0.4855 y Accuracy=0.8494
#
# saved-model-059-0.8185.hdf5
# Loss=0.4978 y Accuracy=0.8393
#
# saved-model-060-0.8160.hdf5
# Loss=0.5135 y Accuracy=0.8388
#
# saved-model-061-0.8115.hdf5
# Loss=0.5507 y Accuracy=0.8318
#
# saved-model-062-0.8365.hdf5
# Loss=0.4754 y Accuracy=0.8425
#
# saved-model-063-0.8130.hdf5
# Loss=0.5474 y Accuracy=0.8418
#
# saved-model-064-0.8475.hdf5
# Loss=0.4502 y Accuracy=0.8683
#
# saved-model-065-0.8405.hdf5
# Loss=0.4620 y Accuracy=0.8541
#
# saved-model-066-0.8525.hdf5
# Loss=0.4631 y Accuracy=0.8604
#
# saved-model-067-0.8345.hdf5
# Loss=0.4520 y Accuracy=0.8576
#
# saved-model-068-0.8420.hdf5
# Loss=0.4654 y Accuracy=0.8539
#
# saved-model-069-0.8335.hdf5
# Loss=0.4565 y Accuracy=0.8545
#
# saved-model-070-0.8520.hdf5
# Loss=0.4470 y Accuracy=0.8640
#
# saved-model-071-0.8330.hdf5
# Loss=0.4787 y Accuracy=0.8446
#
# saved-model-072-0.7955.hdf5
# Loss=0.5455 y Accuracy=0.8215
#
# saved-model-073-0.8450.hdf5
# Loss=0.4311 y Accuracy=0.8674
#
# saved-model-074-0.8415.hdf5
# Loss=0.4329 y Accuracy=0.8639
#
# saved-model-075-0.8435.hdf5
# Loss=0.4598 y Accuracy=0.8606
#
# saved-model-076-0.8310.hdf5
# Loss=0.4789 y Accuracy=0.8522
#
# saved-model-077-0.8480.hdf5
# Loss=0.4339 y Accuracy=0.8683
#
# saved-model-078-0.8480.hdf5
# Loss=0.4285 y Accuracy=0.8679
#
# saved-model-079-0.8600.hdf5
# Loss=0.4067 y Accuracy=0.8804
#
# saved-model-080-0.8520.hdf5
# ---------------------------------------------------------------------------
# ResourceExhaustedError                    Traceback (most recent call last)
# <ipython-input-12-f95d25ba8475> in <module>
# ----> 1 Final_Results_Test(log_Dir)
#
# <ipython-input-6-22717b7ece63> in Final_Results_Test(PATH_trained_models)
#       9             print(filename)
#      10             model = tf.keras.models.load_model(PATH_trained_models+'/'+filename, custom_objects={'Tanh3':Tanh3})
# ---> 11             loss,accuracy = model.evaluate(X_test, y_test,verbose=0)
#      12             print(f'Loss={loss:.4f} y Accuracy={accuracy:0.4f}'+'\n')
#      13             BandAccTest  = accuracy
#
# ~/anaconda3/envs/tf22/lib/python3.8/site-packages/tensorflow/python/keras/engine/training.py in _method_wrapper(self, *args, **kwargs)
#      64   def _method_wrapper(self, *args, **kwargs):
#      65     if not self._in_multi_worker_mode():  # pylint: disable=protected-access
# ---> 66       return method(self, *args, **kwargs)
#      67
#      68     # Running inside `run_distribute_coordinator` already.
#
# ~/anaconda3/envs/tf22/lib/python3.8/site-packages/tensorflow/python/keras/engine/training.py in evaluate(self, x, y, batch_size, verbose, sample_weight, steps, callbacks, max_queue_size, workers, use_multiprocessing, return_dict)
#    1079                 step_num=step):
#    1080               callbacks.on_test_batch_begin(step)
# -> 1081               tmp_logs = test_function(iterator)
#    1082               # Catch OutOfRangeError for Datasets of unknown size.
#    1083               # This blocks until the batch has finished executing.
#
# ~/anaconda3/envs/tf22/lib/python3.8/site-packages/tensorflow/python/eager/def_function.py in __call__(self, *args, **kwds)
#     578         xla_context.Exit()
#     579     else:
# --> 580       result = self._call(*args, **kwds)
#     581
#     582     if tracing_count == self._get_tracing_count():
#
# ~/anaconda3/envs/tf22/lib/python3.8/site-packages/tensorflow/python/eager/def_function.py in _call(self, *args, **kwds)
#     642         # Lifting succeeded, so variables are initialized and we can run the
#     643         # stateless function.
# --> 644         return self._stateless_fn(*args, **kwds)
#     645     else:
#     646       canon_args, canon_kwds = \
#
# ~/anaconda3/envs/tf22/lib/python3.8/site-packages/tensorflow/python/eager/function.py in __call__(self, *args, **kwargs)
#    2418     with self._lock:
#    2419       graph_function, args, kwargs = self._maybe_define_function(args, kwargs)
# -> 2420     return graph_function._filtered_call(args, kwargs)  # pylint: disable=protected-access
#    2421
#    2422   @property
#
# ~/anaconda3/envs/tf22/lib/python3.8/site-packages/tensorflow/python/eager/function.py in _filtered_call(self, args, kwargs)
#    1659       `args` and `kwargs`.
#    1660     """
# -> 1661     return self._call_flat(
#    1662         (t for t in nest.flatten((args, kwargs), expand_composites=True)
#    1663          if isinstance(t, (ops.Tensor,
#
# ~/anaconda3/envs/tf22/lib/python3.8/site-packages/tensorflow/python/eager/function.py in _call_flat(self, args, captured_inputs, cancellation_manager)
#    1743         and executing_eagerly):
#    1744       # No tape is watching; skip to running the function.
# -> 1745       return self._build_call_outputs(self._inference_function.call(
#    1746           ctx, args, cancellation_manager=cancellation_manager))
#    1747     forward_backward = self._select_forward_and_backward_functions(
#
# ~/anaconda3/envs/tf22/lib/python3.8/site-packages/tensorflow/python/eager/function.py in call(self, ctx, args, cancellation_manager)
#     591       with _InterpolateFunctionError(self):
#     592         if cancellation_manager is None:
# --> 593           outputs = execute.execute(
#     594               str(self.signature.name),
#     595               num_outputs=self._num_outputs,
#
# ~/anaconda3/envs/tf22/lib/python3.8/site-packages/tensorflow/python/eager/execute.py in quick_execute(op_name, num_outputs, inputs, attrs, ctx, name)
#      57   try:
#      58     ctx.ensure_initialized()
# ---> 59     tensors = pywrap_tfe.TFE_Py_Execute(ctx._handle, device_name, op_name,
#      60                                         inputs, attrs, num_outputs)
#      61   except core._NotOkStatusException as e:
#
# ResourceExhaustedError:  OOM when allocating tensor with shape[32,192,256,256] and type float on /job:localhost/replica:0/task:0/device:GPU:0 by allocator GPU_0_bfc
# 	 [[node model/concatenate/concat (defined at <ipython-input-6-22717b7ece63>:11) ]]
# Hint: If you want to see a list of allocated tensors when OOM happens, add report_tensor_allocations_upon_oom to RunOptions for current allocation info.
#  [Op:__inference_test_function_1150709]
#
# Function call stack:
# test_function

# %%
# GRAPHICS OF THE THREE (TRAIN, TEST AND VALIDATION) CURVES
graphics(history, AccTest, LossTest, log_Dir, model_Name, lossTEST, lossTRAIN, lossVALID, accuracyTEST, accuracyTRAIN, accuracyVALID)
